# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.shape
# Out:
# (301, 9)

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df['Is_Duplicate'] = df.duplicated()

df.drop(columns = ['Is_Duplicate'], inplace = True)

# %%
df = df.drop_duplicates(subset=['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
       'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'])

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [299 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.histplot(df['Selling_Price'], bins=20, kde=True)
plt.xlabel('Selling Price')
plt.ylabel('Frequency')
plt.title('Distribution of Selling Prices')
plt.show()

# %%
# checking the distribution of categorical data
print(df['Fuel_Type'].value_counts())
print(df['Selling_type'].value_counts())
print(df['Transmission'].value_counts())
# Out:
# Petrol    239
# Diesel     58
# CNG         2
# Name: Fuel_Type, dtype: int64
# Dealer        193
# Individual    106
# Name: Selling_type, dtype: int64
# Manual       260
# Automatic     39
# Name: Transmission, dtype: int64

# %%
# encoding "Fuel_Type" Column
df.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)

# encoding "Seller_Type" Column
df.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)

# encoding "Transmission" Column
df.replace({'Transmission':{'Manual':0,'Automatic':1}},inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23480\1019405577.py in <module>
#       1 # encoding "Fuel_Type" Column
# ----> 2 df.replace({'Fuel_Type':{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
#       3
#       4 # encoding "Seller_Type" Column
#       5 df.replace({'Selling_type':{'Dealer':0,'Individual':1}},inplace=True)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4170             limit=limit,
#    4171             regex=regex,
# -> 4172             method=method,
#    4173         )
#    4174
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6644
#    6645             return self.replace(
# -> 6646                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6647             )
#    6648         else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4170             limit=limit,
#    4171             regex=regex,
# -> 4172             method=method,
#    4173         )
#    4174
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6664                                 value=value[c],
#    6665                                 inplace=False,
# -> 6666                                 regex=regex,
#    6667                             )
#    6668                     return None if inplace else res
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4176             limit=limit,
#    4177             regex=regex,
# -> 4178             method=method,
#    4179         )
#    4180
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6697                         dest_list=value,
#    6698                         inplace=inplace,
# -> 6699                         regex=regex,
#    6700                     )
#    6701
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     611             return _compare_or_regex_search(values, s, regex)
#     612
# --> 613         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#     614
#     615         result_blocks = []
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#     611             return _compare_or_regex_search(values, s, regex)
#     612
# --> 613         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#     614
#     615         result_blocks = []
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\managers.py in comp(s, regex)
#     609                     maybe_convert_objects(values), s.asm8, regex
#     610                 )
# --> 611             return _compare_or_regex_search(values, s, regex)
#     612
#     613         masks = [comp(s, regex) for i, s in enumerate(src_list)]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\internals\managers.py in _compare_or_regex_search(a, b, regex)
#    1934
#    1935         raise TypeError(
# -> 1936             f"Cannot compare types {repr(type_names[0])} and {repr(type_names[1])}"
#    1937         )
#    1938     return result
#
# TypeError: Cannot compare types 'ndarray(dtype=int64)' and 'str'

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          0
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          0
# 3    wagon r  2011           2.85           4.15        5200          0
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          0
# 298     city  2009           3.35          11.00       87934          0
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          0
#
#      Selling_type  Transmission  Owner
# 0               0             0      0
# 1               0             0      0
# 2               0             0      0
# 3               0             0      0
# 4               0             0      0
# ..            ...           ...    ...
# 296             0             0      0
# 297             0             0      0
# 298             0             0      0
# 299             0             0      0
# 300             0             0      0
#
# [299 rows x 9 columns]

# %%
#Modeling
X = df.drop(['Car_Name','Selling_Price'],axis=1)
Y = df['Selling_Price']

# %%
#Evalution and Visualization
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=13)

model = LinearRegression()

model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared (R2): {r2:.2f}")
# Out:
# Mean Squared Error (MSE): 2.41
# R-squared (R2): 0.89

# %%
plt.figure(figsize=(10, 6))
plt.scatter(Y_test, Y_pred, alpha=0.5)
plt.xlabel('Actual Selling Price')
plt.ylabel('Predicted Selling Price')
plt.title('Actual vs. Predicted Selling Prices (Linear Regression)')
plt.show()
